# %%
#Celso-26-tp555
#código_desenvolvido_em_14/08/2020

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

m = 1000

x = np.random.uniform(0,1,m)

w = np.random.randn(1000)

y = 1.2 + 2.3*x + 10*w

fig, ax = plt.subplots()
ax.plot(x, y, '.')

fig.savefig("test.png")
plt.show()
