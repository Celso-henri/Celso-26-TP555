# %%
a = '-1/sqrt(2) -j1/sqrt(2)'
b = '-1/sqrt(2) + j1/sqrt(2)'
c = '1/sqrt(2) - j1/sqrt(2)'
d = '1/sqrt(2) + j1/sqrt(2)'

print (' a representa -1/sqrt(2) -j1/sqrt(2)\n b representa -1/sqrt(2) + j1/sqrt(2)\n c representa 1/sqrt(2) - j1/sqrt(2)\n d representa 1/sqrt(2) + j1/sqrt(2)')



def demodulator ():
    number = input ('Digite uma letra entre a, b, c e d')
    if 'a' in number:
        print ('0')
    if 'b' in number:
        print('1')
    if 'c' in number:
        print ('2')
    if 'd' in number:
        print('3')
        
demodulator ()



import numpy as np
import matplotlib.pyplot as plt

namostragemdesimbolos = 1000

a = np.random.randint(0, 4, namostragemdesimbolos) 


modulator = a
x_degrees = modulator*360/4.0 + 45 

x_radians = x_degrees*np.pi/180.0 




symbols = np.cos(x_radians) + 1j*np.sin(x_radians) 

print (symbols)
# Out:
#  a representa -1/sqrt(2) -j1/sqrt(2)
#  b representa -1/sqrt(2) + j1/sqrt(2)
#  c representa 1/sqrt(2) - j1/sqrt(2)
#  d representa 1/sqrt(2) + j1/sqrt(2)
# Digite uma letra entre a, b, c e dc
# 2
# [-0.70710678+0.70710678j  0.70710678-0.70710678j -0.70710678+0.70710678j
#   0.70710678+0.70710678j  0.70710678-0.70710678j -0.70710678-0.70710678j
#  -0.70710678+0.70710678j -0.70710678+0.70710678j -0.70710678+0.70710678j
#   0.70710678-0.70710678j  0.70710678+0.70710678j -0.70710678-0.70710678j
#   0.70710678+0.70710678j  0.70710678+0.70710678j  0.70710678+0.70710678j
#   0.70710678+0.70710678j -0.70710678-0.70710678j  0.70710678-0.70710678j
#   0.70710678-0.70710678j -0.70710678+0.70710678j  0.70710678+0.70710678j
#  -0.70710678+0.70710678j -0.70710678+0.70710678j  0.70710678-0.70710678j
#   0.70710678-0.70710678j  0.70710678-0.70710678j  0.70710678-0.70710678j
#  -0.70710678-0.70710678j -0.70710678-0.70710678j -0.70710678-0.70710678j
# ...

# %%
# Out:
# [0 3 3 2 3 3 2 3 0 2 0 2 2 1 1 3 0 2 1 3 0 0 2 1 3 0 2 3 2 2 1 1 1 1 1 1 2
#  1 0 0 0 0 3 1 3 2 1 2 1 0 3 2 3 3 3 2 2 3 3 1 3 1 0 0 0 3 3 1 2 1 2 2 3 2
#  0 2 2 1 1 1 0 1 2 1 1 0 3 1 1 3 3 2 1 0 2 1 0 3 2 2 2 2 1 3 3 0 0 0 1 0 2
#  0 2 3 0 2 3 2 1 1 3 3 1 0 0 0 0 3 2 0 1 3 0 3 0 1 3 2 1 2 0 1 2 1 3 3 2 1
#  1 3 2 2 2 3 2 0 2 3 2 3 3 2 0 0 0 3 0 3 1 1 3 1 2 0 0 3 2 2 0 3 0 0 0 1 2
#  0 1 1 0 3 3 3 1 0 2 2 3 1 2 0 0 0 0 2 3 1 0 0 1 1 2 2 0 2 1 2 0 2 2 3 2 1
#  1 0 3 3 3 0 0 1 3 0 0 0 1 3 2 0 3 1 1 0 2 1 0 0 3 0 2 0 1 2 0 0 1 1 3 3 0
#  2 0 2 2 0 0 2 3 3 1 0 1 1 2 3 3 0 0 3 1 0 0 3 2 0 2 3 1 3 0 1 1 0 2 2 3 3
#  0 0 3 1 0 2 2 0 2 2 1 2 0 1 3 0 3 1 1 2 3 0 3 1 0 2 2 3 0 1 0 0 2 3 3 1 1
#  1 0 1 1 3 1 1 2 0 3 0 2 2 2 2 1 0 1 3 2 3 3 3 1 2 2 0 2 2 1 0 0 0 2 0 3 0
#  3 3 2 0 3 1 0 3 2 3 2 0 0 0 1 1 0 1 0 2 2 0 2 1 0 2 3 2 0 2 1 2 0 2 0 1 3
#  2 1 3 0 2 0 1 2 0 2 1 1 0 3 1 2 3 1 2 1 3 0 1 2 2 0 2 1 2 3 1 3 1 1 1 0 3
# ...
